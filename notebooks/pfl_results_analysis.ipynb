# %% [markdown]
# # 个性化联邦学习（PFL）结果分析
#
# 用于浏览全部 PFL 结果、展示单次运行、比较多个算法，以及比较单算法的多组参数。通用逻辑位于 `utils/results.py`。

# %%
import sys
from collections import Counter
from pathlib import Path

current = Path.cwd().resolve()
PROJECT_ROOT = next(path for path in (current, *current.parents) if (path / 'pyproject.toml').is_file())
NOTEBOOK_DIR = PROJECT_ROOT / 'notebooks'
if str(NOTEBOOK_DIR) not in sys.path:
    sys.path.insert(0, str(NOTEBOOK_DIR))

from utils.results import (
    algorithm_names, configure_plots, discover_runs, load_checkpoint,
    plot_algorithm_comparison, plot_algorithm_runs,
    plot_parameter_comparison, plot_run, read_log, runs_table,
    select_runs, show_run_details,
)

configure_plots()
PFL_ALGORITHMS = algorithm_names(PROJECT_ROOT / 'algo' / 'pfl')
PFL_RUNS = discover_runs(PROJECT_ROOT, algorithms=PFL_ALGORITHMS)
print(f'PFL 运行 {len(PFL_RUNS)} 次。')
print(dict(sorted(Counter(run.algorithm for run in PFL_RUNS).items())))

# %% [markdown]
# ## 1. 结果概览与筛选
#
# 可以按运行属性或 `args.json` 中的任意参数筛选。

# %%
runs_table(PFL_RUNS, limit=30)

# selected = select_runs(PFL_RUNS, algorithm='fedproto', dataset='cifar10', status='completed')
# runs_table(selected, limit=None)

# %% [markdown]
# ## 2. 单次运行或单个算法展示

# %%
# selected = select_runs(PFL_RUNS, algorithm='fedproto', status='completed')
# show_run_details(selected[0], PFL_RUNS)
# plot_run(selected[0], PFL_RUNS)
# plot_algorithm_runs(PFL_RUNS, 'fedproto', filters={'dataset': 'cifar10'})

# %% [markdown]
# ## 3. 多算法对比
#
# 匹配到多个 trial 时绘制均值和标准差阴影；请固定数据集、划分、模型等控制变量。

# %%
# fig, axis, compared = plot_algorithm_comparison(
#     PFL_RUNS, ['local', 'fedper', 'fedrep'],
#     filters={'dataset': 'cifar10', 'partition': 'dirichlet', 'status': 'completed'},
# )

# %% [markdown]
# ## 4. 单算法参数对比
#
# `vary` 支持一个参数或多个参数组成的配置组合。

# %%
# fig, axis, groups = plot_parameter_comparison(
#     PFL_RUNS, 'fedala', ['eta', 'rand_percent'],
#     filters={'dataset': 'cifar10', 'status': 'completed'},
# )

# %% [markdown]
# ## 5. 日志与 checkpoint

# %%
# run = PFL_RUNS[0]
# print(read_log(run, PFL_RUNS, tail=20))
# checkpoint = load_checkpoint(run, PFL_RUNS)
